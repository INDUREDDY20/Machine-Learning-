# %%
import pandas as pd 
import numpy as np 
from matplotlib import pyplot as plt

# %%
sal = pd.read_csv(r"C:\Users\INDU PRIYA\OneDrive\Attachments\Desktop\ML Models\Salary_Data.csv")
sal
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
sal.shape
# Out:
# (30, 2)

# %%
sal.dtypes
# Out:
# YearsExperience    float64
# Salary             float64
# dtype: object

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
sal.describe()
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
import seaborn as sns 
sns.scatterplot(x = sal['YearsExperience'],y = sal['Salary'])
plt.xlabel("Years of Experience")
plt.ylabel("Salary")
plt.show()

# %%
x = sal[['YearsExperience']]
y = sal['Salary']

# %%
from sklearn.linear_model import LinearRegression

# %%
slr = LinearRegression()

# %%
slr.fit(x,y)
# Out:
# LinearRegression()

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=5,shuffle=True)
x_train,x_test,y_train,y_test
# Out:
# (    YearsExperience
#  21              7.1
#  28             10.3
#  0               1.1
#  17              5.3
#  5               2.9
#  1               1.3
#  27              9.6
#  12              4.0
#  20              6.8
#  19              6.0
#  24              8.7
#  7               3.2
#  4               2.2
#  8               3.2
#  9               3.7
#  16              5.1
#  22              7.9
#  6               3.0
#  15              4.9
#  14              4.5
#  3               2.0,
#      YearsExperience
#  11              4.0
#  29             10.5
#  23              8.2
#  25              9.0
#  18              5.9
#  10              3.9
#  2               1.5
#  13              4.1
#  26              9.5,
#  21     98273.0
#  28    122391.0
#  0      39343.0
#  17     83088.0
#  5      56642.0
#  1      46205.0
#  27    112635.0
#  12     56957.0
#  20     91738.0
#  19     93940.0
#  24    109431.0
#  7      54445.0
#  4      39891.0
#  8      64445.0
# ...

# %%
y_pred_train = slr.predict(x_train)
y_pred_train
# Out:
# array([ 92886.932681  , 123126.81210966,  36187.15875227,  75877.00050238,
#         53197.09093089,  38077.15121656, 116511.83848464,  63592.04948449,
#         90051.94398456,  82491.9741274 , 108006.87239533,  56032.07962732,
#         46582.11730587,  56032.07962732,  60757.06078805,  73987.00803809,
#        100446.90253816,  54142.08716303,  72097.0155738 ,  68317.03064522,
#         44692.12484158])

# %%
y_pred_test = slr.predict(x_test)
y_pred_test
# Out:
# array([ 63592.04948449, 125016.80457395, 103281.8912346 , 110841.86109176,
#         81546.97789525,  62647.05325234,  39967.14368085,  64537.04571663,
#        115566.84225249])

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_train,y_pred_train)
# Out:
# 0.9489906544170471

# %%
r2_score(y_test,y_pred_test)
# Out:
# 0.9658720658160301
